# %%
print("Hello world")
# Out:
# Hello world

# %%
h = "Hello world "
print(h * 5)
# Out:
# Hello world Hello world Hello world Hello world Hello world

# %%
h = "Hello world\n"
print(h * 5)
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world

# %%
h = "Hello world\n"
h * 5
# Out:
# 'Hello world\nHello world\nHello world\nHello world\nHello world\n'
